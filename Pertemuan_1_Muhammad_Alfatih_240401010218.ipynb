# %% [markdown]
# <a href="https://colab.research.google.com/github/fatih-sudo/data-science-2026/blob/main/Pertemuan_1_Muhammad_Alfatih_240401010218.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # UTS Data Science - Pertemuan 1: Notebook Pertama Data Science
#
# ### Identitas Mahasiswa
# * **Nama Lengkap:** Muhammad Alfatih
# * **NIM:** 240401010218
# * **Kelas:** IF 401
# * **Program Studi:** PJJ Informatika

# %%
# ================================================
# PERTEMUAN 1: Notebook Pertama Data Science
# ================================================
print("Hello, Data Science!")
print("Selamat datang di mata kuliah Pengantar Data Science!")
# Out:
# Hello, Data Science!
# Selamat datang di mata kuliah Pengantar Data Science!

# %%
nama = "Muhammad Alfatih"
angkatan = 2024
ipk = 3.65
aktif = True

print(f"Nama     : {nama}")
print(f"Angkatan : {angkatan}")
print(f"IPK      : {ipk}")
print(f"Aktif    : {aktif}")
# Out:
# Nama     : Muhammad Alfatih
# Angkatan : 2024
# IPK      : 3.65
# Aktif    : True

# %%
tools = ["Python", "Google Colab", "Jupyter Notebook", "GitHub"]
print("\nTools Data Science yang akan kita pelajari:")
for i, tool in enumerate(tools, 1):
    print(f" {i}. {tool}")
# Out:
# Tools Data Science yang akan kita pelajari:
#  1. Python
#  2. Google Colab
#  3. Jupyter Notebook
#  4. GitHub

# %%
def perkenalan(nama, prodi, angkatan):
    """Fungsi untuk menampilkan perkenalan mahasiswa."""
    return f"Hai! Saya {nama} dari {prodi}, angkatan {angkatan}."

hasil = perkenalan("Muhammad Alfatih", "Informatika", 2024)
print(hasil)
# Out:
# Hai! Saya Muhammad Alfatih dari Informatika, angkatan 2024.

# %% [markdown]
# ## Kesimpulan Pertemuan 1
#
# * **Apa yang dipelajari:** Dasar-dasar ekosistem Data Science, setup environment, serta review dasar pemrograman Python (variabel, tipe data, looping, dan fungsi).
# * **Temuan Utama:** Python memiliki sintaksis yang sederhana dan sangat fleksibel, sehingga sangat ideal digunakan untuk manipulasi data ke depannya.
